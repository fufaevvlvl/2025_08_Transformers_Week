# %%
Астрологи объявляют Неделю Трансформеров!

# %%
from IPython.display import Image
Image('0_Title.jpg', width=750, height=300 )

# %% [markdown]
# Но не тех, что с Майклом Беем, а тех, что внутри ChatGPT, DeepSeek и других ИИ-сервисов.
# Если хотите понять или освежить в памяти, как они на самом деле работают — этот конспект для вас.
#
# Что будет в обзоре:
# 1. Краткая история трансформеров – от зарождения до доминирования в NLP.
# 2. Математические инсайты – внимание (attention), слои, нормализация… но без лишних формул.
# 3. Как это применяется – примеры кода и «живые» модели для экспериментов.
# 4. Что нас ждёт? – новые идеи, которые могут улучшить трансформеров.
#
# Всё — в виде лаконичных объяснений, ключевых формул и полезных ссылок (никакой воды).
#
# P.S. Если после прочтения вам захочется покритиковать меня или вступить в дискуссию -
# всегда на связи.
